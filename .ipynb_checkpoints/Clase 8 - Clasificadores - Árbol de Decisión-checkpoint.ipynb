# %% [markdown]
# # Inteligencia Aritificial con Python:Clasificadores

# %% [markdown]
# ## Árbol de decisión

# %% [markdown]
# ![image.png](attachment:72171cbb-a4ed-4435-b7a1-ae9d4476b299.png)![image.png](attachment:bb3011bd-3e10-4078-b9af-e1460ae902fa.png)

# %%
# Importar bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Importar el separador de muestras para entretenimiento y pruebas
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import metrics

# %%
# Cargar el dataset
data = sns.load_dataset('iris')

# %%
# Separación de datos en Entrenamiento y Prueba
train, test = train_test_split(data, test_size=0.4, stratify=data['species'], random_state=42)

# %%
# Separación de la etiqueta de clase <<Y>> y atributos <<X>>
# Conjunto de entrenamiento
X_train = train[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
Y_train = train['species']
# Conjunto de pruebas
X_test = test[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
Y_test = test['species']

# %%
# Árbol de decisión 
mod_dt = DecisionTreeClassifier(max_depth=3, random_state=1)
# Ajustar/Entrenar el modelo 
mod_dt.fit(X_train, Y_train)
# Predecir resultados sobre el conjunto de pruebas
prediccion = mod_dt.predict(X_test)

# %%
# Importancia de cada predictor
mod_dt.feature_importances_
# Out:
# array([0.        , 0.        , 0.42430866, 0.57569134])

# %%
# Etiquetas de datos 
fn = ['sepal_length', 'sepal_width', 'petal_length', 'sepal_width']
cn = ['setosa', 'versicolor', 'virginica']

# %%
# Visualizar las reglas de clasificacion 
plt.figure(figsize=(10,8))
plot_tree(mod_dt, feature_names=fn, class_names=cn, filled=True)
# Out:
# [Text(0.375, 0.875, 'sepal_width <= 0.7\ngini = 0.667\nsamples = 90\nvalue = [30, 30, 30]\nclass = setosa'),
#  Text(0.25, 0.625, 'gini = 0.0\nsamples = 30\nvalue = [30, 0, 0]\nclass = setosa'),
#  Text(0.3125, 0.75, 'True  '),
#  Text(0.5, 0.625, 'petal_length <= 4.95\ngini = 0.5\nsamples = 60\nvalue = [0, 30, 30]\nclass = versicolor'),
#  Text(0.4375, 0.75, '  False'),
#  Text(0.25, 0.375, 'sepal_width <= 1.65\ngini = 0.121\nsamples = 31\nvalue = [0, 29, 2]\nclass = versicolor'),
#  Text(0.125, 0.125, 'gini = 0.0\nsamples = 28\nvalue = [0, 28, 0]\nclass = versicolor'),
#  Text(0.375, 0.125, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(0.75, 0.375, 'sepal_width <= 1.7\ngini = 0.067\nsamples = 29\nvalue = [0, 1, 28]\nclass = virginica'),
#  Text(0.625, 0.125, 'gini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(0.875, 0.125, 'gini = 0.0\nsamples = 26\nvalue = [0, 0, 26]\nclass = virginica')]

# %%
eficiencia = metrics.accuracy_score(Y_test, prediccion)
eficiencia
# Out:
# 0.9833333333333333
